# %% [markdown]
# Notebook test

# %%
import numpy as np
import pandas as pd

# %%
param_func = 'divide'
param_var_x = 2
param_var_y = 5

# %%
my_var3 = param_var_x + param_var_y

# %%
def math(x: float, y: float, func: str) -> float:
    """Function does a calculation based on the given function"""

    if func == 'add':
        return x + y
    elif func == 'distract':
        return x - y
    elif func == 'multiply':
        return x * y
    elif func == 'divide':
        if y != 0:
            return x / y
        else:
            return 0
    elif func == "modulo":
        return x % y
    else:
        return 0

# %%
var_math = math(param_var_x, param_var_y, param_func)
print(var_math)
# Out:
# 0.4

# %%
param_func_mult = 'multiply'
param_var_x2 = 80001
param_var_y2 = 0.2

# %%
var_math2 = math(param_var_x2, param_var_y2, param_func_mult)
print(var_math2)
# Out:
# 16000.2
